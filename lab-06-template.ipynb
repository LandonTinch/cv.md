# %% [markdown]
# ## Lab 06
#
# Complete the questions in the provided Python code cells after moving this file to your DASC1104/scripts directory. Make sure to comment your code! To submit, push your notebook to GitLab once you have correctly answered all the questions, no later than SUNDAY, 24-SEPT, AT 5:00 PM. No credit will be given for assignments with time stamps later than 5:00 PM.

# %% [markdown]
# ## Problem 1
#
# Would you rather be given a million dollars (option 1), or a penny that gets doubled every day for 30 days (option 2)? Write the Python code to figure out how much your penny would grow after thirty days. For each day, print the day number and the number of total pennies you'd have on that day. The first three lines of output should look like this:
#
# >Day 1: 2
#
# >Day 2: 4
#
# >Day 3: 8

# %%
import numpy as np

# %%
# Problem 1 solution here

money = 1
days = 0

while days <= 29:
    money*=2
    days+=1
    print("Day",days,":",money)
# Out:
# Day 1 : 2
# Day 2 : 4
# Day 3 : 8
# Day 4 : 16
# Day 5 : 32
# Day 6 : 64
# Day 7 : 128
# Day 8 : 256
# Day 9 : 512
# Day 10 : 1024
# Day 11 : 2048
# Day 12 : 4096
# Day 13 : 8192
# Day 14 : 16384
# Day 15 : 32768
# Day 16 : 65536
# Day 17 : 131072
# Day 18 : 262144
# Day 19 : 524288
# Day 20 : 1048576
# Day 21 : 2097152
# Day 22 : 4194304
# Day 23 : 8388608
# Day 24 : 16777216
# Day 25 : 33554432
# Day 26 : 67108864
# Day 27 : 134217728
# Day 28 : 268435456
# Day 29 : 536870912
# Day 30 : 1073741824

# %% [markdown]
# ## Problem 2
#
# What is the difference, in dollars, between options 1 and 2?

# %%
# Problem 2 solution here
mil = 1000000
differnce = money - mil
print("The differnce is:",differnce)
# Out:
# The differnce is: 1072741824

# %% [markdown]
# ## Problem 3
#
# Given the list `a[]` below, write some Python code to select all elements of the list that are greater than or equal to 20. Put them into a new list, `b[]`.

# %%
a = np.array([77, 89, 4, 33, 12, 998, 22, 1, 11, 44, 13, 23, 45, 7])

# Problem 3 solution here'"01 DASC 1003 - 
b = a[a>=20]

print(b)
# Out:
# [ 77  89  33 998  22  44  23  45]

# %% [markdown]
# ## Problem 4
#
# Print the items in b[] in ascending numeric order. Print the items as a single comma separated line. Your output should look like this:
#
# >22, 23, 33, 44, 45, 77, 89, 998

# %%
# Problem 4 solution here
b.sort()
print(b)
# Out:
# [ 22  23  33  44  45  77  89 998]

# %% [markdown]
# ## Problem 5
#
# Print all of the names from the list `d[]` in alphabetical order. It may help to create a new list rather than trying to generate the output directly from `d[]`. Your output should look like this:
#
# >Abby
#
# >Annelise
#
# >Bobby
#
# >Hayden
#
# >Melissa
#
# >Todd

# %%
d = ['Melissa', 44, 'zebra', '!', 'Todd',
      ['Detroit Tigers', 'Abby',
       ['Bobby', 'Hayden', 3,
        ['green gloves', 'Annelise'
        ]
       ]
      ]
     ]


# Problem 5 solution here
names = np.array(["Melissh","Todd","Abby"])
names.sort()
print(names)
# Out:
# ['Abby' 'Melissh' 'Todd']

# %%
# Out:
# ['Abby' 'Melissh' 'Todd']
